# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
sal = pd.read_csv('Salaries.csv')
sal
# Out:
#           Id             EmployeeName  \
# 0          1           NATHANIEL FORD
# 1          2             GARY JIMENEZ
# 2          3           ALBERT PARDINI
# 3          4        CHRISTOPHER CHONG
# 4          5          PATRICK GARDNER
# 5          6           DAVID SULLIVAN
# 6          7                ALSON LEE
# 7          8            DAVID KUSHNER
# 8          9           MICHAEL MORRIS
# 9         10       JOANNE HAYES-WHITE
# 10        11            ARTHUR KENNEY
# 11        12         PATRICIA JACKSON
# 12        13        EDWARD HARRINGTON
# 13        14              JOHN MARTIN
# 14        15           DAVID FRANKLIN
# 15        16          RICHARD CORRIEA
# 16        17                 AMY HART
# 17        18           SEBASTIAN WONG
# 18        19               MARTY ROSS
# 19        20            ELLEN MOFFATT
# 20        21               VENUS AZAR
# 21        22             JUDY MELINEK
# 22        23            GEORGE GARCIA
# 23        24            VICTOR WYRSCH
# 24        25          JOSEPH DRISCOLL
# 25        26             GREGORY SUHR
# 26        27              JOHN HANLEY
# 27        28           RAYMOND GUZMAN
# 28        29           DENISE SCHMITT
# 29        30            MONICA FIELDS
# ...      ...                      ...
# 65504  65505               Zhihua Tan
# 65505  65506               Mark Nicco
# 65506  65507            Xiao Dong Cai
# 65507  65508              Jose Aranda
# 65508  65509              Connie Chen
# 65509  65510                   Lai Lu
# 65510  65511               Sue Kaplan
# 65511  65512       Richard Weinberger
# 65512  65513               David Dinh
# 65513  65514               Teresa Liu
# 65514  65515     Gretel Davila Lacayo
# 65515  65516             Kurt Ledesma
# 65516  65517              Erin Bowman
# 65517  65518           Sharon Fincher
# 65518  65519             Nweke Hearne
# 65519  65520         Richard Halloran
# 65520  65521             Roldan Ditan
# 65521  65522              Billy Vance
# 65522  65523                  Mary Ma
# 65523  65524  Flor Palacios-Rodriguez
# 65524  65525           Fayard Acluche
# 65525  65526            Eric Heinicke
# 65526  65527             Cecilia Chiu
# 65527  65528        Michael Taylor Jr
# 65528  65529         Helene Campagnet
# 65529  65530         Grace Montelongo
# 65530  65531            Erika Lovejoy
# 65531  65532              Jeffrey Tom
# 65532  65533           Mark Bellinger
# 65533  65534         Gerald Fowler Jr
#
#                                                JobTitle    BasePay  \
# 0        GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                       CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                       CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                  WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4          DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# 5                             ASSISTANT DEPUTY CHIEF II  118602.00
# 6                    BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 7                        DEPUTY DIRECTOR OF INVESTMENTS  256576.96
# 8                    BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9                CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10     ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# 11                      CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 12                          EXECUTIVE CONTRACT EMPLOYEE  294580.02
# 13                                    DEPARTMENT HEAD V  271329.03
# 14                   BATTALION CHIEF, (FIRE DEPARTMENT)  174872.64
# 15                   COMMANDER III, (POLICE DEPARTMENT)  198778.01
# 16                                    DEPARTMENT HEAD V  268604.57
# 17                CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87
# 18                   BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63
# 19                           ASSISTANT MEDICAL EXAMINER  257510.59
# 20                           ASSISTANT MEDICAL EXAMINER  257510.48
# 21                           ASSISTANT MEDICAL EXAMINER  257510.44
# 22                            CAPTAIN, FIRE SUPPRESSION  140546.88
# 23                   BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63
# 24                            CAPTAIN, FIRE SUPPRESSION  140546.86
# 25                                      CHIEF OF POLICE  256470.41
# 26                            CAPTAIN, FIRE SUPPRESSION   92080.80
# 27                   BATTALION CHIEF, (FIRE DEPARTMENT)  168692.59
# 28                 DEPUTY CHIEF III (POLICE DEPARTMENT)  261717.60
# 29         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  246225.60
# ...                                
# 65514         0.00     870.00   2630.16   28692.00          31322.16  2012
# 65515      1271.26     702.72   9449.83   21870.98          31320.81  2012
# 65516         0.00     784.22   2456.97   28859.24          31316.21  2012
# 65517         0.00     274.63  11641.57   19662.60          31304.17  2012
# 65518         0.00     976.55  10902.39   20401.47          31303.86  2012
# 65519         0.00    1053.74   8725.56   22576.94          31302.50  2012
# 65520         0.00       0.00  10805.32   20485.50          31290.82  2012
# 65521         0.00     891.99   8155.49   23134.79          31290.28  2012
# 65522         0.00   18804.19   5556.96   25727.62          31284.58  2012
# 65523       453.38     725.09   2488.81   28778.01          31266.82  2012
# 65524       422.04    3276.29  10469.95   20796.46          31266.41  2012
# 65525      4210.46      10.80   2444.82   28816.36          31261.18  2012
# 65526         0.00       0.00   7248.69   24011.39          31260.08  2012
# 65527        78.43     592.45   9697.01   21541.56          31238.57  2012
# 65528         0.00    1210.16   5691.68   25535.04          31226.72  2012
# 65529      4778.92    1561.85   6236.06   24950.87          31186.93  2012
# 65530         0.00    6634.63   7285.59   23878.64          31164.23  2012
# 65531         0.00       0.00   2893.82   28260.00          31153.82  2012
# 65532      1217.31   12195.89   7235.12   23867.33          31102.45  2012
# 65533        93.71       5.05  11654.47   19445.53          31100.00  2012
#
#        Notes         Agency  Status
# 0        NaN  San Francisco     NaN
# 1        NaN  San Francisco     NaN
# 2        NaN  San Francisco     NaN
# 3        NaN  San Francisco     NaN
# 4        NaN  San Francisco     NaN
# 5        NaN  San Francisco     NaN
# 6        NaN  San Francisco     NaN
# 7        NaN  San Francisco     NaN
# 8        NaN  San Francisco     NaN
# 9        NaN  San Francisco     NaN
# 10       NaN  San Francisco     NaN
# 11       NaN  San Francisco     NaN
# 12       NaN  San Francisco     NaN
# 13       NaN  San Francisco     NaN
# 14       NaN  San Francisco     NaN
# 15       NaN  San Francisco     NaN
# 16       NaN  San Francisco     NaN
# 17       NaN  San Francisco     NaN
# 18       NaN  San Francisco     NaN
# 19       NaN  San Francisco     NaN
# 20       NaN  San Francisco     NaN
# 21       NaN  San Francisco     NaN
# 22       NaN  San Francisco     NaN
# 23       NaN  San Francisco     NaN
# 24       NaN  San Francisco     NaN
# 25       NaN  San Francisco     NaN
# 26       NaN  San Francisco     NaN
# 27       NaN  San Francisco     NaN
# 28       NaN  San Francisco     NaN
# 29       NaN  San Francisco     NaN
# ...      ...            ...     ...
# 65504    NaN  San Francisco     NaN
# 65505    NaN  San Francisco     NaN
# 65506    NaN  San Francisco     NaN
# 65507    NaN  San Francisco     NaN
# 65508    NaN  San Francisco     NaN
# 65509    NaN  San Francisco     NaN
# 65510    NaN  San Francisco     NaN
# 65511    NaN  San Francisco     NaN
# 65512    NaN  San Francisco     NaN
# 65513    NaN  San Francisco     NaN
# 65514    NaN  San Francisco     NaN
# 65515    NaN  San Francisco     NaN
# 65516    NaN  San Francisco     NaN
# 65517    NaN  San Francisco     NaN
# 65518    NaN  San Francisco     NaN
# 65519    NaN  San Francisco     NaN
# 65520    NaN  San Francisco     NaN
# 65521    NaN  San Francisco     NaN
# 65522    NaN  San Francisco     NaN
# 65523    NaN  San Francisco     NaN
# 65524    NaN  San Francisco     NaN
# 65525    NaN  San Francisco     NaN
# 65526    NaN  San Francisco     NaN
# 65527    NaN  San Francisco     NaN
# 65528    NaN  San Francisco     NaN
# 65529    NaN  San Francisco     NaN
# 65530    NaN  San Francisco     NaN
# 65531    NaN  San Francisco     NaN
# 65532    NaN  San Francisco     NaN
# 65533    NaN  San Francisco     NaN
#
# [65534 rows x 13 columns]

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].min()]
# Out:
#           Id        EmployeeName                                    JobTitle  \
# 36156  36157      PAULETTE ADAMS  STATIONARY ENGINEER, WATER TREATMENT PLANT
# 36157  36158       KAUKAB MOHSIN                            TRANSIT OPERATOR
# 36158  36159  JOSEPHINE MCCREARY                                  MANAGER IV
#
#        BasePay  OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# 36156      0.0          0.0       0.0       NaN       0.0               0.0
# 36157      0.0          0.0       0.0       NaN       0.0               0.0
# 36158      0.0          0.0       0.0       NaN       0.0               0.0
#
#        Year  Notes         Agency  Status
# 36156  2011    NaN  San Francisco     NaN
# 36157  2011    NaN  San Francisco     NaN
# 36158  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
sal.groupby('Year').mean() ['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    79782.254013
# Name: BasePay, dtype: float64

# %% [markdown]
# ** How many unique job titles are there? **

# %%
sal['JobTitle'].nunique()
# Out:
# 2056

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# TRANSIT OPERATOR    2388
# Transit Operator    2003
# SPECIAL NURSE       1402
# REGISTERED NURSE    1219
# Registered Nurse    1207
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
sum(sal[sal['Year'] == 2011]['JobTitle'].value_counts() == 1)
# Out:
# 200

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
# Out:
#   File "<ipython-input-61-048d7694cdf8>", line 2
#     if 'chief' in title.lower().split():
#      ^
# IndentationError: expected an indented block

# %%
# Out:
#   File "<ipython-input-62-c668f1db788f>", line 1
#     In [48]:
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
sal['title_len'] = sal['JobTitle'].apply(len)

# %%
sal[['TotalPayBenefits','title_len']].corr()
# Out:
#                   TotalPayBenefits  title_len
# TotalPayBenefits          1.000000  -0.038745
# title_len                -0.038745   1.000000

# %% [markdown]
# # Great Job!
